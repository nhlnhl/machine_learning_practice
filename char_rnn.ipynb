# %%
import codecs
import os
import collections
import _pickle as cPickle
#from six.moves import cPickle
import numpy as np


class TextLoader():
    def __init__(self, data_dir, batch_size, seq_length, encoding='utf-8'):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.seq_length = seq_length
        self.encoding = encoding

        input_file = os.path.join(data_dir, "input.txt")
        vocab_file = os.path.join(data_dir, "vocab.pkl")
        tensor_file = os.path.join(data_dir, "data.npy")

        if not (os.path.exists(vocab_file) and os.path.exists(tensor_file)):
            print("reading text file")
            self.preprocess(input_file, vocab_file, tensor_file)
        else:
            print("loading preprocessed files")
            self.load_preprocessed(vocab_file, tensor_file)
        self.create_batches()
        self.reset_batch_pointer()

    def preprocess(self, input_file, vocab_file, tensor_file):
        with codecs.open(input_file, "r", encoding=self.encoding) as f:
        # with codecs.open(input_file, 'rb') as f:
            data = f.read()
        counter = collections.Counter(data)
        count_pairs = sorted(counter.items(), key=lambda x: -x[1])
        self.chars, _ = zip(*count_pairs)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        with open(vocab_file, 'wb') as f:
            cPickle.dump(self.chars, f)
        self.tensor = np.array(list(map(self.vocab.get, data)))
        np.save(tensor_file, self.tensor)

    def load_preprocessed(self, vocab_file, tensor_file):
        with open(vocab_file, 'rb') as f:
            self.chars = cPickle.load(f)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        self.tensor = np.load(tensor_file)
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

    def create_batches(self):
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

        # When the data (tensor) is too small,
        # let's give them a better error message
        if self.num_batches == 0:
            assert False, "Not enough data. Make seq_length and batch_size small."

        self.tensor = self.tensor[:self.num_batches * self.batch_size * self.seq_length]
        xdata = self.tensor
        ydata = np.copy(self.tensor)
        ydata[:-1] = xdata[1:]
        ydata[-1] = xdata[0]
        self.x_batches = np.split(xdata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)
        self.y_batches = np.split(ydata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)

    def next_batch(self):
        x, y = self.x_batches[self.pointer], self.y_batches[self.pointer]
        self.pointer += 1
        return x, y

    def reset_batch_pointer(self):
        self.pointer = 0

# %%
# -*- coding: utf-8 -*-
# Char-RNN 예제
# Author : solaris33
# Project URL : http://solarisailab.com/archives/2487
# GitHub Repository : https://github.com/solaris33/char-rnn-tensorflow/
# Reference : https://github.com/sherjilozair/char-rnn-tensorflow

import tensorflow as tf
import numpy as np
#from utils import TextLoader

# 학습에 필요한 설정값들을 지정합니다.
data_dir = 'data/tinyshakespeare' # 셰익스피어 희곡 <리처드 3세> 데이터로 학습
#data_dir = 'data/linux' # <Linux 소스코드> 데이터로 학습
batch_size = 50 # Training : 50, Sampling : 1
seq_length = 50 # Training : 50, Sampling : 1
hidden_size = 128   # 히든 레이어의 노드 개수
learning_rate = 0.002
num_epochs = 2
num_hidden_layers = 2
grad_clip = 5   # Gradient Clipping에 사용할 임계값

# TextLoader를 이용해서 데이터를 불러옵니다.
data_loader = TextLoader(data_dir, batch_size, seq_length)
# 학습데이터에 포함된 모든 단어들을 나타내는 변수인 chars와 chars에 id를 부여해 dict 형태로 만든 vocab을 선언합니다.
chars = data_loader.chars 
vocab = data_loader.vocab
vocab_size = data_loader.vocab_size # 전체 단어개수

# 인풋데이터와 타겟데이터, 배치 사이즈를 입력받기 위한 플레이스홀더를 설정합니다.
input_data = tf.placeholder(tf.int32, shape=[None, None], name="input")  # input_data : [batch_size, seq_length])
target_data = tf.placeholder(tf.int32, shape=[None, None], name="target") # target_data : [batch_size, seq_length])
state_batch_size = tf.placeholder(tf.int32, shape=[])      # Training : 50, Sampling : 1

# RNN의 마지막 히든레이어의 출력을 소프트맥스 출력값으로 변환해주기 위한 변수들을 선언합니다.
# hidden_size -> vocab_size
softmax_w = tf.Variable(tf.random_normal(shape=[hidden_size, vocab_size]), dtype=tf.float32, name="weight")
softmax_b = tf.Variable(tf.random_normal(shape=[vocab_size]), dtype=tf.float32, name="bias")

# num_hidden_layers만큼 LSTM cell(히든레이어)를 선언합니다.
cells = []
for _ in range(0, num_hidden_layers):
    cell = tf.nn.rnn_cell.BasicLSTMCell(hidden_size)
    cells.append(cell)

# cell을 종합해서 RNN을 정의합니다.
cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)
#cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_size, state_is_tuple=True)

# 인풋데이터를 변환하기 위한 Embedding Matrix를 선언합니다.
# vocab_size -> hidden_size
embedding = tf.Variable(tf.random_normal(shape=[vocab_size, hidden_size]), dtype=tf.float32, name="embedding")
inputs = tf.nn.embedding_lookup(embedding, input_data)

# 초기 state 값을 0으로 초기화합니다.
initial_state = cell.zero_state(state_batch_size, tf.float32)

# 학습을 위한 tf.nn.dynamic_rnn을 선언합니다.
# outputs : [batch_size, seq_length, hidden_size]
outputs, final_state = tf.nn.dynamic_rnn(cell, inputs, initial_state=initial_state, dtype=tf.float32)
# ouputs을 [batch_size * seq_length, hidden_size]] 형태로 바꿉니다.
output = tf.reshape(outputs, [-1, hidden_size])

# 최종 출력값을 설정합니다.
# logits : [batch_size * seq_length, vocab_size]
logits = tf.matmul(output, softmax_w) + softmax_b
probs = tf.nn.softmax(logits)

# Cross Entropy 손실 함수를 정의합니다. 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=target_data))

# 옵티마이저를 선언하고 옵티마이저에 Gradient Clipping을 적용합니다.
# grad_clip(=5)보다 큰 Gradient를 5로 Clippin합니다.
tvars = tf.trainable_variables()
grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.apply_gradients(zip(grads, tvars))

tf.summary.scalar('loss', loss)

# 세션을 열고 학습을 진행합니다.
with tf.Session() as sess:
    # 변수들에 초기값을 할당합니다.
    sess.run(tf.global_variables_initializer())
    
    # tensorboard --logdir=./logs --port=any number you want
    merged = tf.summary.merge_all()
    writer = tf.summary.FileWriter('./logs', sess.graph)
    
    for e in range(num_epochs):
        data_loader.reset_batch_pointer()
        # 초기 상태값을 지정합니다.
        state = sess.run(initial_state, feed_dict={state_batch_size : batch_size})

        for b in range(data_loader.num_batches):
            # x, y 데이터를 불러옵니다.
            x, y = data_loader.next_batch()
            # y에 one_hot 인코딩을 적용합니다. 
            y = tf.one_hot(y, vocab_size)            # y : [batch_size, seq_length, vocab_size]
            y = tf.reshape(y, [-1, vocab_size])       # y : [batch_size * seq_length, vocab_size]
            y = y.eval()

            # feed-dict에 사용할 값들과 LSTM 초기 cell state(feed_dict[c])값과 hidden layer 출력값(feed_dict[h])을 지정합니다.
            feed_dict = {input_data : x, target_data: y, state_batch_size : batch_size}
            for i, (c, h) in enumerate(initial_state):
                feed_dict[c] = state[i].c
                feed_dict[h] = state[i].h

            # 한스텝 학습을 진행합니다.
            _, loss_print, state = sess.run([train_step, loss, final_state], feed_dict=feed_dict)

            print("{}(학습한 배치개수)/{}(학습할 배치개수), 반복(epoch): {}, 손실함수(loss): {:.3f}".format(
                          e * data_loader.num_batches + b,
                          num_epochs * data_loader.num_batches,
                          (e+1), 
                          loss_print))
            
            summary = sess.run(merged, feed_dict={input_data : x, target_data: y, state_batch_size : batch_size})
            writer.add_summary(summary, b)

    print("트레이닝이 끝났습니다!")   
    

    # 샘플링 시작
    print("샘플링을 시작합니다!")
    num_sampling = 4000  # 생성할 글자(Character)의 개수를 지정합니다. 
    prime = u' '         # 시작 글자를 ' '(공백)으로 지정합니다.
    sampling_type = 1    # 샘플링 타입을 설정합니다.
    state = sess.run(cell.zero_state(1, tf.float32)) # RNN의 최초 state값을 0으로 초기화합니다.

    # Random Sampling을 위한 weighted_pick 함수를 정의합니다.
    def weighted_pick(weights):
        t = np.cumsum(weights)
        s = np.sum(weights)
        return(int(np.searchsorted(t, np.random.rand(1)*s)))

    ret = prime       # 샘플링 결과를 리턴받을 ret 변수에 첫번째 글자를 할당합니다.
    char = prime[-1]   # Char-RNN의 첫번쨰 인풋을 지정합니다.  
    for n in range(num_sampling):
        x = np.zeros((1, 1))
        x[0, 0] = vocab[char]

        # RNN을 한스텝 실행하고 Softmax 행렬을 리턴으로 받습니다.
        feed_dict = {input_data: x, state_batch_size : 1, initial_state: state}
        [probs_result, state] = sess.run([probs, final_state], feed_dict=feed_dict)         

        # 불필요한 차원을 제거합니다.
        # probs_result : (1,65) -> p : (65)
        p = np.squeeze(probs_result)

        # 샘플링 타입에 따라 3가지 종류로 샘플링 합니다.
        # sampling_type : 0 -> 다음 글자를 예측할때 항상 argmax를 사용
        # sampling_type : 1(defualt) -> 다음 글자를 예측할때 항상 random sampling을 사용
        # sampling_type : 2 -> 다음 글자를 예측할때 이전 글자가 ' '(공백)이면 random sampling, 그렇지 않을 경우 argmax를 사용
        if sampling_type == 0:
            sample = np.argmax(p)
        elif sampling_type == 2:
            if char == ' ':
                sample = weighted_pick(p)
            else:
                sample = np.argmax(p)
        else:
            sample = weighted_pick(p)

        pred = chars[sample]
        ret += pred     # 샘플링 결과에 현재 스텝에서 예측한 글자를 추가합니다. (예를들어 pred=L일 경우, ret = HEL -> HELL)
        char = pred     # 예측한 글자를 다음 RNN의 인풋으로 사용합니다.

    print("샘플링 결과:")
    print(ret)
# Out:
# C:\Users\joobong\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# loading preprocessed files
# WARNING:tensorflow:From <ipython-input-2-8ad99cf12a11>:70: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# 0(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 5.344
# 1(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.383
# 2(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.993
# 3(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.974
# 4(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.761
# 5(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.621
# 6(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.602
# 7(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.505
# 8(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.321
# 9(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.325
# 10(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.271
# 11(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.264
# 12(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.177
# 13(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.155
# 14(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.171
# 15(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.118
# 16(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.087
# 17(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.069
# 18(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.006
# 19(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.990
# 20(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.978
# 21(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.985
# 22(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.934
# 23(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.930
# 24(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.888
# 25(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.879
# 26(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.820
# 27(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.825
# 28(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.762
# 29(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.773
# 30(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.784
# 31(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.826
# 32(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.674
# 33(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.705
# 34(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.674
# 35(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.677
# 36(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.738
# 37(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.666
# 38(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.658
# 39(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.633
# 40(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.656
# 41(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.577
# 42(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.550
# 43(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.497
# 44(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.566
# 45(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.532
# 46(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.476
# 47(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.506
# 48(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.509
# 49(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.492
# 50(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.464
# 51(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.434
# 52(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.432
# 53(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.450
# 54(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.422
# 55(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.419
# 56(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.342
# 57(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.373
# 58(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.346
# 59(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.342
# 60(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.396
# 61(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.409
# 62(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.342
# 63(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.398
# 64(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.330
# 65(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.327
# 66(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.316
# 67(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.302
# 68(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.352
# 69(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.318
# 70(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.269
# 71(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.295
# 72(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.285
# 73(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.247
# 74(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.241
# 75(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.245
# 76(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.242
# 77(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.249
# 78(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.260
# 79(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.244
# 80(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.267
# 81(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.179
# 82(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.219
# 83(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.212
# 84(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.240
# 85(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.179
# 86(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.161
# 87(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.139
# 88(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.240
# 89(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.144
# 90(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.125
# 91(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.120
# 92(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.151
# 93(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.140
# 94(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.193
# 95(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.183
# 96(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.163
# 97(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.121
# 98(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.093
# 99(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.169
# 100(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.121
# 101(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.122
# 102(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.140
# 103(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.108
# 104(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.100
# 105(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.107
# 106(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.085
# 107(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.099
# 108(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.106
# 109(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.045
# 110(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.018
# 111(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.082
# 112(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.083
# 113(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.084
# 114(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.112
# 115(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.111
# 116(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.078
# 117(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.105
# 118(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.044
# 119(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.977
# 120(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.054
# 121(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.038
# 122(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.005
# 123(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.013
# 124(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.044
# 125(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.089
# 126(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.011
# 127(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.036
# 128(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.068
# 129(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.975
# 130(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.964
# 131(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.008
# 132(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.062
# 133(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.991
# 134(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.979
# 135(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.029
# 136(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.041
# 137(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.047
# 138(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.035
# 139(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.067
# 140(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.048
# 141(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.023
# 142(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.972
# 143(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.974
# 144(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.992
# 145(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.993
# 146(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.964
# 147(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.953
# 148(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.994
# 149(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.996
# 150(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.932
# 151(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.985
# 152(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.962
# 153(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.957
# 154(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.971
# 155(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.982
# 156(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.918
# 157(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.962
# 158(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.948
# 159(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.977
# 160(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.918
# 161(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.044
# 162(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.986
# 163(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.947
# 164(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.009
# 165(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.980
# 166(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.933
# 167(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 168(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.960
# 169(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.993
# 170(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.990
# 171(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.995
# 172(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.945
# 173(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.931
# 174(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.958
# 175(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.978
# 176(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.941
# 177(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.911
# 178(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.892
# 179(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.865
# 180(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.890
# 181(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.940
# 182(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.936
# 183(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.920
# 184(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.813
# 185(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.906
# 186(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.906
# 187(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.932
# 188(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.905
# 189(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.835
# 190(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.906
# 191(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.815
# 192(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.878
# 193(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.880
# 194(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.904
# 195(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.879
# 196(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.860
# 197(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.908
# 198(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.960
# 199(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.941
# 200(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.917
# 201(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.891
# 202(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.911
# 203(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.870
# 204(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.897
# 205(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.881
# 206(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 207(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.922
# 208(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.952
# 209(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.868
# 210(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.886
# 211(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.822
# 212(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.881
# 213(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.878
# 214(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.808
# 215(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.857
# 216(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.879
# 217(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 218(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.827
# 219(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.856
# 220(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.843
# 221(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.921
# 222(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 223(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.849
# 224(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.836
# 225(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.815
# 226(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.926
# 227(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.840
# 228(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.874
# 229(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.880
# 230(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.881
# 231(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 232(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.837
# 233(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 234(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.847
# 235(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.843
# 236(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.857
# 237(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.830
# 238(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.840
# 239(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.847
# 240(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.844
# 241(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.793
# 242(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.812
# 243(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.871
# 244(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.802
# 245(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.802
# 246(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.835
# 247(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.822
# 248(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.874
# 249(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.773
# 250(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.862
# 251(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.754
# 252(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.853
# 253(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 254(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.820
# 255(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.811
# 256(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.799
# 257(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 258(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.840
# 259(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.783
# 260(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.767
# 261(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.759
# 262(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 263(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.807
# 264(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.752
# 265(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.851
# 266(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.850
# 267(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 268(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.787
# 269(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.796
# 270(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.780
# 271(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.823
# 272(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.740
# 273(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.835
# 274(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.797
# 275(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.819
# 276(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.798
# 277(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.807
# 278(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.781
# 279(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.815
# 280(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.781
# 281(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.839
# 282(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 283(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.756
# 284(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.778
# 285(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.762
# 286(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 287(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.809
# 288(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.801
# 289(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.745
# 290(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.765
# 291(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.782
# 292(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 293(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.800
# 294(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.791
# 295(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.782
# 296(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.800
# 297(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.734
# 298(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.823
# 299(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 300(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.707
# 301(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.767
# 302(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.697
# 303(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 304(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.784
# 305(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.774
# 306(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.697
# 307(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.783
# 308(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.803
# 309(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.794
# 310(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.754
# 311(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.803
# 312(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.797
# 313(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.797
# 314(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.699
# 315(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.750
# 316(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.743
# 317(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.775
# 318(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.728
# 319(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 320(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.722
# 321(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.735
# 322(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.735
# 323(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.696
# 324(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.735
# 325(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.723
# 326(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 327(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.718
# 328(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.763
# 329(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 330(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 331(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.757
# 332(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 333(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.654
# 334(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 335(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 336(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 337(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 338(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.821
# 339(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.662
# 340(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.753
# 341(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.649
# 342(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.723
# 343(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.712
# 344(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.640
# 345(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.732
# 346(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 347(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.766
# 348(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.691
# 349(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.805
# 350(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.762
# 351(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.702
# 352(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 353(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.637
# 354(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.639
# 355(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 356(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.757
# 357(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.758
# 358(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 359(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.707
# 360(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 361(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.674
# 362(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 363(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 364(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.734
# 365(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.687
# 366(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.692
# 367(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 368(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.710
# 369(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.669
# 370(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.807
# 371(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 372(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.740
# 373(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.712
# 374(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 375(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.709
# 376(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.707
# 377(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 378(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.674
# 379(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.666
# 380(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.739
# 381(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 382(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 383(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.699
# 384(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.682
# 385(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.749
# 386(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.711
# 387(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 388(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 389(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.651
# 390(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 391(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.723
# 392(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.712
# 393(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 394(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.656
# 395(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 396(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.650
# 397(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.634
# 398(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.684
# 399(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.649
# 400(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.717
# 401(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 402(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.708
# 403(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.723
# 404(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.688
# 405(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.699
# 406(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.721
# 407(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 408(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 409(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 410(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 411(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.647
# 412(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.702
# 413(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.653
# 414(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.651
# 415(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 416(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 417(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.633
# 418(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.637
# 419(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.728
# 420(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 421(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 422(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.728
# 423(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.716
# 424(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 425(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.668
# 426(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 427(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.668
# 428(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.682
# 429(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.703
# 430(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.637
# 431(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.773
# 432(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.659
# 433(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 434(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.666
# 435(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.662
# 436(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.658
# 437(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.662
# 438(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.734
# 439(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.634
# 440(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.697
# 441(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 442(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.626
# 443(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.614
# 444(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.670
# 445(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.661
# 446(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.775
# 447(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.655
# 448(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.635
# 449(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.658
# 450(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.721
# 451(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.691
# 452(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.685
# 453(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.697
# 454(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 455(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 456(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.699
# 457(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.606
# 458(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.662
# 459(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 460(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 461(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 462(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.705
# 463(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.611
# 464(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 465(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 466(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.560
# 467(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.606
# 468(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 469(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 470(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 471(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 472(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 473(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 474(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.649
# 475(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 476(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.638
# 477(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.684
# 478(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 479(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 480(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.660
# 481(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 482(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.755
# 483(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.732
# 484(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.645
# 485(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.688
# 486(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.675
# 487(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.695
# 488(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.627
# 489(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 490(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.673
# 491(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.657
# 492(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 493(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 494(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 495(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 496(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.600
# 497(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 498(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.592
# 499(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.627
# 500(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.645
# 501(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.609
# 502(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 503(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.645
# 504(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.611
# 505(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 506(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.672
# 507(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.632
# 508(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 509(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.667
# 510(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 511(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.636
# 512(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 513(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.671
# 514(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.683
# 515(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.625
# 516(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.625
# 517(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 518(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.660
# 519(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 520(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.583
# 521(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.635
# 522(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.630
# 523(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.629
# 524(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.624
# 525(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.659
# 526(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 527(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.511
# 528(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 529(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.615
# 530(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 531(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.640
# 532(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 533(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.567
# 534(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.672
# 535(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.613
# 536(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 537(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 538(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.624
# 539(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.585
# 540(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 541(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.678
# 542(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.637
# 543(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.629
# 544(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.543
# 545(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.651
# 546(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.564
# 547(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 548(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.652
# 549(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.583
# 550(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.612
# 551(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 552(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 553(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.576
# 554(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.648
# 555(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 556(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 557(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 558(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.627
# 559(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 560(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.608
# 561(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.621
# 562(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 563(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.651
# 564(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.622
# 565(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 566(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.600
# 567(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.621
# 568(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 569(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 570(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 571(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.655
# 572(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 573(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.633
# 574(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.659
# 575(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 576(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.526
# 577(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 578(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.654
# 579(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.592
# 580(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.578
# 581(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 582(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.648
# 583(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.646
# 584(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.640
# 585(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.633
# 586(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 587(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 588(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 589(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.560
# 590(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 591(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.616
# 592(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 593(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 594(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 595(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.585
# 596(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 597(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.611
# 598(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.592
# 599(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 600(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 601(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.600
# 602(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.584
# 603(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.610
# 604(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 605(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 606(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 607(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.690
# 608(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 609(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.594
# 610(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.638
# 611(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 612(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 613(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 614(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.613
# 615(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.652
# 616(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.634
# 617(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.633
# 618(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.628
# 619(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 620(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 621(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.650
# 622(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.598
# 623(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 624(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 625(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.551
# 626(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.579
# 627(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.566
# 628(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.618
# 629(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.601
# 630(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.484
# 631(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 632(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 633(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.599
# 634(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.585
# 635(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 636(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 637(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 638(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 639(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 640(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 641(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 642(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 643(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.582
# 644(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.612
# 645(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.630
# 646(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.642
# 647(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.589
# 648(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 649(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.519
# 650(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 651(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 652(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.601
# 653(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.624
# 654(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.666
# 655(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 656(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.583
# 657(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.533
# 658(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 659(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.561
# 660(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 661(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 662(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.578
# 663(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 664(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 665(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 666(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 667(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.593
# 668(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 669(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.578
# 670(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 671(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.538
# 672(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.642
# 673(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 674(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.595
# 675(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 676(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.620
# 677(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.578
# 678(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 679(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.626
# 680(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 681(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 682(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 683(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.552
# 684(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.583
# 685(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 686(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 687(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.544
# 688(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 689(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 690(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.538
# 691(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.557
# 692(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 693(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 694(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.613
# 695(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 696(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.605
# 697(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.510
# 698(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.600
# 699(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 700(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.555
# 701(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 702(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 703(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 704(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.564
# 705(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 706(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.503
# 707(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.544
# 708(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.511
# 709(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 710(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 711(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.612
# 712(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.597
# 713(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.559
# 714(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 715(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 716(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 717(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 718(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 719(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.602
# 720(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 721(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.593
# 722(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 723(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.588
# 724(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 725(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 726(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 727(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 728(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.523
# 729(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.527
# 730(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.567
# 731(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 732(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 733(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.596
# 734(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.585
# 735(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.544
# 736(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.538
# 737(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 738(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 739(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.561
# 740(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.570
# 741(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 742(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 743(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.527
# 744(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.590
# 745(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 746(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.517
# 747(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 748(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 749(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.487
# 750(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.580
# 751(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.565
# 752(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.485
# 753(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 754(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.603
# 755(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 756(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 757(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.604
# 758(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 759(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.600
# 760(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.515
# 761(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 762(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.536
# 763(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.550
# 764(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 765(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.468
# 766(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.496
# 767(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.530
# 768(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 769(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.503
# 770(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 771(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.520
# 772(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.533
# 773(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 774(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.571
# 775(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 776(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.506
# 777(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 778(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 779(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.439
# 780(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 781(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.519
# 782(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.546
# 783(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 784(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.631
# 785(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.491
# 786(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.576
# 787(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.471
# 788(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.542
# 789(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 790(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.469
# 791(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.537
# 792(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 793(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.567
# 794(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 795(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.636
# 796(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.566
# 797(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.533
# 798(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.471
# 799(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.489
# 800(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.468
# 801(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.528
# 802(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 803(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.587
# 804(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 805(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.525
# 806(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 807(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 808(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.485
# 809(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 810(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.551
# 811(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 812(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.483
# 813(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 814(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.542
# 815(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 816(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.608
# 817(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.491
# 818(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.572
# 819(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 820(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 821(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 822(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.545
# 823(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.490
# 824(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.500
# 825(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 826(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 827(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.515
# 828(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.607
# 829(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 830(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 831(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.586
# 832(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.529
# 833(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.563
# 834(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 835(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.472
# 836(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 837(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.532
# 838(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.527
# 839(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.581
# 840(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.492
# 841(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 842(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.488
# 843(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.459
# 844(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.521
# 845(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 846(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.555
# 847(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 848(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.546
# 849(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 850(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.527
# 851(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.539
# 852(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.562
# 853(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 854(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 855(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.540
# 856(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 857(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.509
# 858(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.525
# 859(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 860(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 861(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.522
# 862(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 863(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.503
# 864(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.495
# 865(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.568
# 866(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.523
# 867(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.541
# 868(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 869(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.573
# 870(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 871(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 872(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 873(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 874(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 875(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 876(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 877(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.627
# 878(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 879(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.561
# 880(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 881(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 882(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.493
# 883(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.512
# 884(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.617
# 885(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 886(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.554
# 887(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.454
# 888(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.487
# 889(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.467
# 890(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 891(학습한 배치개수)/892(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.510
# 트레이닝이 끝났습니다!
# 샘플링을 시작합니다!
# 샘플링 결과:
#  villain;
# Whre wilt I'll was dangerous respiests more ay
# Desced mother.
# God ow! Mials to the princhee,
# He brothe fathe, sir, which forlow.
#
# RUTILIO:
# Why, seep be rune.
#
# CORIOLANUS:
# One thy hearth; where's about hold alamk wantable.
# And slew ou means a yourself: old upos,
# Her what!' You so enjury nerved be gues
# As with you will be stile, upon Angelence
# You sounder me, I place ghener, as too all all;
# Or heading dissense me sended: Vill's out urse.
#
# Second Mast, Warwick: in my soung as I will candom
# And flyw the consictlies; he will,
# Is ened him, my Edwil, might there,
# Thenger-life?
#
# TRANIO:
# Mate abus of very life, good, if another hence,
# Than he say word the ponst mere.
#
# PETRUCHIO:
# Say, not souls Hencence me best me in paiding crimior--
#
# First MraSes Lays:
# On Vlocens of the morn.
# Where it you sheet whilst hie hap'd this had your never be
# young sping, let him ends thy take thy! Baunt ills?
#
# Second of his mighterous hath pusineds, please,
# Within quuil of chey: when your me, i' see Turbers:
#
# BENVOLION:
# A marget me doth their life.
#
# Second and Biract MaintaS:
# Come then my hange. Is, in eite thy dangerogue;
# Or sout my horse maid and his darge, and dept slait lie,
# Whiches your lie as I say, sir!
#
# CORIOLANUS:
# We have against to delicle.
#
# ClING HENRY VI
#
# PETER:
# All down, must be courte pocken I quicking he shall I
# Thist? IG us the king's coaming supping as heir
# thinks if you wrothing you? If I cannot not
# As gill, marioke
# I coosies thyselve with hour but I heard?
#
# HENRY BOLINGBROKE:
# hose bleing here.
#
# DUKE VINCENTIO:
# Pay's frides your no lie Edmands; by thy gilling,
# That the pringe Tybread not say.
#
# MERCUTIO:
# I toge ampieriol. That kiss and councle,
# The did the sirching a meanst thyself you!
#
# CAPULET:
# But either seen eye I Wervice awardiverling
# To proviles, where, let me the nubs I may, by the you;
# You are thy lays, me prison yelors,
# For me prisonly head, Beway?
#
# WARWICK:
# I sily way you, compis off-spirits. The sahing,
# Throst blessire, you do my to knower upon
# All armient on'd saint sworng to.
#
# PETER:
# You these helps bleques. What was all suppined,
# Or the sinder do ere some pudes; they sea
# Say, you be when pound underult in my serves,
# Threght doth thou ever I have my oble with death?
#
# Citizens:
# When me she gentle: not, fellow as, sir!
#
# LUCIO:
# I the brothereip all be for'd me to thee:
# A shows thy fall go Orpoor days he shalse deals by.
#
# HERMIONE:
# To the manly chair one in thy bloce, folls,
# ear of the faurthe is now boting him!
#
# ALBOSIO:
# Why, thou dextreight thy quarrel requerquted to suds.
#
# SATLY GANTI:
# Prove why fold-by us which his fatcagess?
# They man? I may appraikes: be toes love,
# Which God that he crocks 'dien man smock's, bold!
# Ay, as friendio, up to sovereing aidle men.
#
# Claptish'd Andeedgeming melian
# Which a doth Papoised wemate,
# Haths, lord, We'clade merriend, sir! Why, Silant I she fear to wails,
# Come beow betide itselge in the wars? How
# With is speak this pattleratue passens, at shy such is
# he were the king so ervall beseing their suppied
# Give ant her are in this slanks puten?
#
# Thirderon?
#
# KING RICHARD III:
# Thence one thy wrong fall his handlen put.
#
# NORTHUMBERLAND:
# Nor full me mean, you king impring infor,
# And ye foolses with souflices? I may warry,
# That me soul gentle me, wills spiter.
#
# AUTOLYCUS:
# Well to soes he very to our more
# This mine dedure thee reding doth timmas
# To moother'd; and feat-plaissual.
#
# LUCIO:
# No with please Mascher, that's heaven find where, sir.
#
# HASTINGS:
# Inseech is the time a marreried,
# it Clary happy thy with them: I say, I;
# Shouldies with his lady sat stirents o'er: Rook, wife
#
# Wust wrothange, peace than dawn'd for.
#
# NORKEO:
# Prithee, I giver I know meilia: me now!
# Away, you Ory mid curchient! Maast netters:
# Why, sir,--
#
# GLOUCESTER:
# Feedly there, me screasure leaving day.
#
# PAULINA:
# Sistor, he away?
#
# DUKE VINCENTIO:
# O what knot what stay this life, that I rage it,
# What whose hath you med love dery much with the own is master
# To that be storle blow to he merry.
#
# BUCKINGHAM:
# Why, soldier, govence, we's bul
