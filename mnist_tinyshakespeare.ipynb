# %%
import codecs
import os
import collections
import _pickle as cPickle
#from six.moves import cPickle
import numpy as np


class TextLoader():
    def __init__(self, data_dir, batch_size, seq_length, encoding='utf-8'):
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.seq_length = seq_length
        self.encoding = encoding

        input_file = os.path.join(data_dir, "input.txt")
        vocab_file = os.path.join(data_dir, "vocab.pkl")
        tensor_file = os.path.join(data_dir, "data.npy")

        if not (os.path.exists(vocab_file) and os.path.exists(tensor_file)):
            print("reading text file")
            self.preprocess(input_file, vocab_file, tensor_file)
        else:
            print("loading preprocessed files")
            self.load_preprocessed(vocab_file, tensor_file)
        self.create_batches()
        self.reset_batch_pointer()

    def preprocess(self, input_file, vocab_file, tensor_file):
        with codecs.open(input_file, "r", encoding=self.encoding) as f:
#        with codecs.open(input_file, 'rb') as f:
            data = f.read()
        counter = collections.Counter(data)
        count_pairs = sorted(counter.items(), key=lambda x: -x[1])
        self.chars, _ = zip(*count_pairs)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        with open(vocab_file, 'wb') as f:
            cPickle.dump(self.chars, f)
        self.tensor = np.array(list(map(self.vocab.get, data)))
        np.save(tensor_file, self.tensor)

    def load_preprocessed(self, vocab_file, tensor_file):
        with open(vocab_file, 'rb') as f:
            self.chars = cPickle.load(f)
        self.vocab_size = len(self.chars)
        self.vocab = dict(zip(self.chars, range(len(self.chars))))
        self.tensor = np.load(tensor_file)
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

    def create_batches(self):
        self.num_batches = int(self.tensor.size / (self.batch_size *
                                                   self.seq_length))

        # When the data (tensor) is too small,
        # let's give them a better error message
        if self.num_batches == 0:
            assert False, "Not enough data. Make seq_length and batch_size small."

        self.tensor = self.tensor[:self.num_batches * self.batch_size * self.seq_length]
        xdata = self.tensor
        ydata = np.copy(self.tensor)
        ydata[:-1] = xdata[1:]
        ydata[-1] = xdata[0]
        self.x_batches = np.split(xdata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)
        self.y_batches = np.split(ydata.reshape(self.batch_size, -1),
                                  self.num_batches, 1)

    def next_batch(self):
        x, y = self.x_batches[self.pointer], self.y_batches[self.pointer]
        self.pointer += 1
        return x, y

    def reset_batch_pointer(self):
        self.pointer = 0

# %%
# -*- coding: utf-8 -*-
# Char-RNN 예제
# Author : solaris33
# Project URL : http://solarisailab.com/archives/2487
# GitHub Repository : https://github.com/solaris33/char-rnn-tensorflow/
# Reference : https://github.com/sherjilozair/char-rnn-tensorflow

import tensorflow as tf
import numpy as np
#from utils import TextLoader

# 학습에 필요한 설정값들을 지정합니다.
#data_dir = 'data/tinyshakespeare' # 셰익스피어 희곡 <리처드 3세> 데이터로 학습
data_dir = 'data/linux' # <Linux 소스코드> 데이터로 학습
batch_size = 50 # Training : 50, Sampling : 1
seq_length = 50 # Training : 50, Sampling : 1
hidden_size = 128   # 히든 레이어의 노드 개수
learning_rate = 0.002
num_epochs = 2
num_hidden_layers = 2
grad_clip = 5   # Gradient Clipping에 사용할 임계값

# TextLoader를 이용해서 데이터를 불러옵니다.
data_loader = TextLoader(data_dir, batch_size, seq_length)
# 학습데이터에 포함된 모든 단어들을 나타내는 변수인 chars와 chars에 id를 부여해 dict 형태로 만든 vocab을 선언합니다.
chars = data_loader.chars 
vocab = data_loader.vocab
vocab_size = data_loader.vocab_size # 전체 단어개수

# 인풋데이터와 타겟데이터, 배치 사이즈를 입력받기 위한 플레이스홀더를 설정합니다.
input_data = tf.placeholder(tf.int32, shape=[None, None])  # input_data : [batch_size, seq_length])
target_data = tf.placeholder(tf.int32, shape=[None, None]) # target_data : [batch_size, seq_length])
state_batch_size = tf.placeholder(tf.int32, shape=[])      # Training : 50, Sampling : 1

# RNN의 마지막 히든레이어의 출력을 소프트맥스 출력값으로 변환해주기 위한 변수들을 선언합니다.
# hidden_size -> vocab_size
softmax_w = tf.Variable(tf.random_normal(shape=[hidden_size, vocab_size]), dtype=tf.float32)
softmax_b = tf.Variable(tf.random_normal(shape=[vocab_size]), dtype=tf.float32)

# num_hidden_layers만큼 LSTM cell(히든레이어)를 선언합니다.
cells = []
for _ in range(0, num_hidden_layers):
    cell = tf.nn.rnn_cell.BasicLSTMCell(hidden_size)
    cells.append(cell)

# cell을 종합해서 RNN을 정의합니다.
cell = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)

# 인풋데이터를 변환하기 위한 Embedding Matrix를 선언합니다.
# vocab_size -> hidden_size
embedding = tf.Variable(tf.random_normal(shape=[vocab_size, hidden_size]), dtype=tf.float32)
inputs = tf.nn.embedding_lookup(embedding, input_data)

# 초기 state 값을 0으로 초기화합니다.
initial_state = cell.zero_state(state_batch_size, tf.float32)

# 학습을 위한 tf.nn.dynamic_rnn을 선언합니다.
# outputs : [batch_size, seq_length, hidden_size]
outputs, final_state = tf.nn.dynamic_rnn(cell, inputs, initial_state=initial_state, dtype=tf.float32)
# ouputs을 [batch_size * seq_length, hidden_size]] 형태로 바꿉니다.
output = tf.reshape(outputs, [-1, hidden_size])

# 최종 출력값을 설정합니다.
# logits : [batch_size * seq_length, vocab_size]
logits = tf.matmul(output, softmax_w) + softmax_b
probs = tf.nn.softmax(logits)

# Cross Entropy 손실 함수를 정의합니다. 
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=target_data))

# 옵티마이저를 선언하고 옵티마이저에 Gradient Clipping을 적용합니다.
# grad_clip(=5)보다 큰 Gradient를 5로 Clippin합니다.
tvars = tf.trainable_variables()
grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
optimizer = tf.train.AdamOptimizer(learning_rate)
train_step = optimizer.apply_gradients(zip(grads, tvars))

# 세션을 열고 학습을 진행합니다.
with tf.Session() as sess:
    # 변수들에 초기값을 할당합니다.
    sess.run(tf.global_variables_initializer())
    
    for e in range(num_epochs):
        data_loader.reset_batch_pointer()
        # 초기 상태값을 지정합니다.
        state = sess.run(initial_state, feed_dict={state_batch_size : batch_size})

        for b in range(data_loader.num_batches):
            # x, y 데이터를 불러옵니다.
            x, y = data_loader.next_batch()
            # y에 one_hot 인코딩을 적용합니다. 
            y = tf.one_hot(y, vocab_size)            # y : [batch_size, seq_length, vocab_size]
            y = tf.reshape(y, [-1, vocab_size])       # y : [batch_size * seq_length, vocab_size]
            y = y.eval()

            # feed-dict에 사용할 값들과 LSTM 초기 cell state(feed_dict[c])값과 hidden layer 출력값(feed_dict[h])을 지정합니다.
            feed_dict = {input_data : x, target_data: y, state_batch_size : batch_size}
            for i, (c, h) in enumerate(initial_state):
                feed_dict[c] = state[i].c
                feed_dict[h] = state[i].h

            # 한스텝 학습을 진행합니다.
            _, loss_print, state = sess.run([train_step, loss, final_state], feed_dict=feed_dict)

            print("{}(학습한 배치개수)/{}(학습할 배치개수), 반복(epoch): {}, 손실함수(loss): {:.3f}".format(
                          e * data_loader.num_batches + b,
                          num_epochs * data_loader.num_batches,
                          (e+1), 
                          loss_print))

    print("트레이닝이 끝났습니다!")   
    

    # 샘플링 시작
    print("샘플링을 시작합니다!")
    num_sampling = 4000  # 생성할 글자(Character)의 개수를 지정합니다. 
    prime = u' '         # 시작 글자를 ' '(공백)으로 지정합니다.
    sampling_type = 1    # 샘플링 타입을 설정합니다.
    state = sess.run(cell.zero_state(1, tf.float32)) # RNN의 최초 state값을 0으로 초기화합니다.

    # Random Sampling을 위한 weighted_pick 함수를 정의합니다.
    def weighted_pick(weights):
        t = np.cumsum(weights)
        s = np.sum(weights)
        return(int(np.searchsorted(t, np.random.rand(1)*s)))

    ret = prime       # 샘플링 결과를 리턴받을 ret 변수에 첫번째 글자를 할당합니다.
    char = prime[-1]   # Char-RNN의 첫번쨰 인풋을 지정합니다.  
    for n in range(num_sampling):
        x = np.zeros((1, 1))
        x[0, 0] = vocab[char]

        # RNN을 한스텝 실행하고 Softmax 행렬을 리턴으로 받습니다.
        feed_dict = {input_data: x, state_batch_size : 1, initial_state: state}
        [probs_result, state] = sess.run([probs, final_state], feed_dict=feed_dict)         

        # 불필요한 차원을 제거합니다.
        # probs_result : (1,65) -> p : (65)
        p = np.squeeze(probs_result)

        # 샘플링 타입에 따라 3가지 종류로 샘플링 합니다.
        # sampling_type : 0 -> 다음 글자를 예측할때 항상 argmax를 사용
        # sampling_type : 1(defualt) -> 다음 글자를 예측할때 항상 random sampling을 사용
        # sampling_type : 2 -> 다음 글자를 예측할때 이전 글자가 ' '(공백)이면 random sampling, 그렇지 않을 경우 argmax를 사용
        if sampling_type == 0:
            sample = np.argmax(p)
        elif sampling_type == 2:
            if char == ' ':
                sample = weighted_pick(p)
            else:
                sample = np.argmax(p)
        else:
            sample = weighted_pick(p)

        pred = chars[sample]
        ret += pred     # 샘플링 결과에 현재 스텝에서 예측한 글자를 추가합니다. (예를들어 pred=L일 경우, ret = HEL -> HELL)
        char = pred     # 예측한 글자를 다음 RNN의 인풋으로 사용합니다.

    print("샘플링 결과:")
    print(ret)
    
    # tensorboard --logdir=./logs --port=any number you want
    merged = tf.summary.merge_all()
    writer = tf.summary.FileWriter('./logs', sess.graph)
# Out:
# C:\Users\joobong\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# reading text file
# WARNING:tensorflow:From <ipython-input-2-8fb150b860e2>:69: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# 0(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 5.060
# 1(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.553
# 2(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.244
# 3(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 4.132
# 4(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.907
# 5(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.759
# 6(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.682
# 7(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.514
# 8(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.508
# 9(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.474
# 10(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.464
# 11(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.456
# 12(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.411
# 13(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.452
# 14(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.385
# 15(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.305
# 16(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.340
# 17(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.296
# 18(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.326
# 19(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.194
# 20(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.215
# 21(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.213
# 22(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.182
# 23(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.135
# 24(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.103
# 25(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.091
# 26(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.065
# 27(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.103
# 28(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.151
# 29(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.063
# 30(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.111
# 31(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.036
# 32(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 3.030
# 33(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.985
# 34(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.926
# 35(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.887
# 36(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.932
# 37(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.822
# 38(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.784
# 39(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.873
# 40(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.749
# 41(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.715
# 42(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.651
# 43(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.631
# 44(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.695
# 45(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.660
# 46(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.674
# 47(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.641
# 48(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.650
# 49(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.651
# 50(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.587
# 51(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.646
# 52(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.543
# 53(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.640
# 54(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.614
# 55(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.512
# 56(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.574
# 57(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.485
# 58(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.530
# 59(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.589
# 60(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.532
# 61(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.493
# 62(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.465
# 63(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.492
# 64(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.447
# 65(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.486
# 66(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.468
# 67(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.414
# 68(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.414
# 69(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.469
# 70(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.361
# 71(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.413
# 72(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.362
# 73(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.337
# 74(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.399
# 75(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.441
# 76(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.377
# 77(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.341
# 78(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.453
# 79(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.331
# 80(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.354
# 81(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.320
# 82(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.254
# 83(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.309
# 84(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.300
# 85(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.321
# 86(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.279
# 87(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.284
# 88(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.187
# 89(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.245
# 90(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.247
# 91(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.237
# 92(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.264
# 93(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.161
# 94(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.222
# 95(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.279
# 96(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.190
# 97(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.249
# 98(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.185
# 99(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.242
# 100(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.269
# 101(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.200
# 102(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.167
# 103(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.070
# 104(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.144
# 105(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.097
# 106(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.079
# 107(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.997
# 108(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.076
# 109(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.037
# 110(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.057
# 111(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.082
# 112(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.027
# 113(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.025
# 114(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.003
# 115(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.984
# 116(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.072
# 117(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.023
# 118(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.987
# 119(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.026
# 120(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.061
# 121(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.043
# 122(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.208
# 123(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.024
# 124(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.012
# 125(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.990
# 126(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.120
# 127(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.099
# 128(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.044
# 129(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.997
# 130(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.940
# 131(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.958
# 132(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.886
# 133(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.973
# 134(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.966
# 135(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.929
# 136(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.973
# 137(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.963
# 138(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.041
# 139(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.984
# 140(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.998
# 141(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.981
# 142(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.955
# 143(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.960
# 144(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.939
# 145(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.944
# 146(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.928
# 147(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.961
# 148(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.963
# 149(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.893
# 150(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.999
# 151(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.912
# 152(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.886
# 153(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 154(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 155(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.908
# 156(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.897
# 157(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.882
# 158(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.858
# 159(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.927
# 160(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 2.020
# 161(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.867
# 162(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.921
# 163(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.863
# 164(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.858
# 165(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.973
# 166(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.988
# 167(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.902
# 168(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.895
# 169(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.843
# 170(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.854
# 171(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.917
# 172(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.888
# 173(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.866
# 174(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.878
# 175(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 176(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.803
# 177(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.806
# 178(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.775
# 179(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.824
# 180(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.825
# 181(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.839
# 182(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 183(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.864
# 184(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.832
# 185(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 186(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.833
# 187(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.741
# 188(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 189(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.782
# 190(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 191(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.746
# 192(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.810
# 193(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.843
# 194(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.820
# 195(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 196(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.830
# 197(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 198(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.852
# 199(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.792
# 200(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.664
# 201(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.812
# 202(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 203(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.796
# 204(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.691
# 205(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.777
# 206(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.779
# 207(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.776
# 208(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.767
# 209(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.734
# 210(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.739
# 211(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.770
# 212(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.727
# 213(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 214(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.751
# 215(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.751
# 216(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.733
# 217(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.765
# 218(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.764
# 219(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.760
# 220(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 221(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.867
# 222(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.647
# 223(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.804
# 224(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.808
# 225(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 226(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.806
# 227(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 228(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.667
# 229(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 230(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.786
# 231(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.734
# 232(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.765
# 233(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.713
# 234(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.705
# 235(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.715
# 236(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.737
# 237(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.683
# 238(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 239(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.747
# 240(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 241(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.687
# 242(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.715
# 243(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 244(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.807
# 245(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 246(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.728
# 247(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 248(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.691
# 249(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 250(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.789
# 251(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.830
# 252(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.658
# 253(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.695
# 254(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 255(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.699
# 256(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.751
# 257(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.710
# 258(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.587
# 259(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.648
# 260(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.680
# 261(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.727
# 262(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.781
# 263(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.813
# 264(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.838
# 265(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.772
# 266(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.690
# 267(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.607
# 268(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.763
# 269(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.800
# 270(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 271(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 272(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 273(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.594
# 274(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.814
# 275(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.618
# 276(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.730
# 277(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.671
# 278(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.648
# 279(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.724
# 280(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.715
# 281(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.686
# 282(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 283(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.675
# 284(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.669
# 285(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.683
# 286(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.736
# 287(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.631
# 288(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.572
# 289(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.661
# 290(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.681
# 291(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 292(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.646
# 293(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.744
# 294(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.685
# 295(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 296(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.575
# 297(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.575
# 298(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.619
# 299(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.645
# 300(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.670
# 301(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.679
# 302(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.737
# 303(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.704
# 304(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.610
# 305(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.856
# 306(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.701
# 307(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.598
# 308(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.663
# 309(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 310(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.722
# 311(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.706
# 312(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.633
# 313(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.659
# 314(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.613
# 315(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.652
# 316(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.647
# 317(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.643
# 318(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.594
# 319(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.549
# 320(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.604
# 321(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.590
# 322(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.574
# 323(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.630
# 324(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.556
# 325(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.630
# 326(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 327(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.619
# 328(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.607
# 329(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.580
# 330(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.597
# 331(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.510
# 332(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.583
# 333(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.622
# 334(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.612
# 335(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.591
# 336(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.465
# 337(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.508
# 338(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.461
# 339(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.424
# 340(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.486
# 341(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.560
# 342(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.539
# 343(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.475
# 344(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.455
# 345(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.560
# 346(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.702
# 347(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.713
# 348(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.700
# 349(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.673
# 350(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.725
# 351(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.698
# 352(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.639
# 353(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 354(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 355(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.574
# 356(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.613
# 357(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 358(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.645
# 359(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.654
# 360(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.623
# 361(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.677
# 362(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.530
# 363(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.525
# 364(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.579
# 365(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.548
# 366(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.600
# 367(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.525
# 368(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.641
# 369(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.468
# 370(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.616
# 371(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.626
# 372(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.629
# 373(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.551
# 374(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.525
# 375(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.645
# 376(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.554
# 377(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.608
# 378(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.556
# 379(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.553
# 380(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.640
# 381(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.668
# 382(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.726
# 383(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.641
# 384(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.635
# 385(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.511
# 386(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.594
# 387(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.571
# 388(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.636
# 389(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.601
# 390(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.502
# 391(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.566
# 392(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.737
# 393(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.554
# 394(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.619
# 395(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.669
# 396(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.693
# 397(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.660
# 398(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.703
# 399(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.631
# 400(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.678
# 401(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.655
# 402(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.533
# 403(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.562
# 404(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.620
# 405(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.550
# 406(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.785
# 407(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.753
# 408(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.694
# 409(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.720
# 410(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.638
# 411(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.682
# 412(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.527
# 413(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.451
# 414(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.493
# 415(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.453
# 416(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.498
# 417(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.499
# 418(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.552
# 419(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.502
# 420(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.498
# 421(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.417
# 422(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.563
# 423(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.605
# 424(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.506
# 425(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.599
# 426(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.642
# 427(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.590
# 428(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.532
# 429(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.534
# 430(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.560
# 431(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.520
# 432(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.545
# 433(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.554
# 434(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.666
# 435(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.525
# 436(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.500
# 437(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.541
# 438(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.564
# 439(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.624
# 440(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.589
# 441(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.606
# 442(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.523
# 443(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.572
# 444(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.637
# 445(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.588
# 446(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.552
# 447(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.444
# 448(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.548
# 449(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.603
# 450(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.606
# 451(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.592
# 452(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.610
# 453(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.571
# 454(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.545
# 455(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.546
# 456(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.553
# 457(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.591
# 458(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.509
# 459(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.569
# 460(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.550
# 461(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.572
# 462(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.531
# 463(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.494
# 464(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.566
# 465(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.568
# 466(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.523
# 467(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.541
# 468(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.475
# 469(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.515
# 470(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.445
# 471(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.422
# 472(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.430
# 473(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.500
# 474(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.484
# 475(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.500
# 476(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.526
# 477(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.498
# 478(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.535
# 479(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.502
# 480(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.551
# 481(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.430
# 482(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.498
# 483(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.447
# 484(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.466
# 485(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.455
# 486(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.461
# 487(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.523
# 488(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.487
# 489(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.453
# 490(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.504
# 491(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.510
# 492(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.499
# 493(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.492
# 494(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.405
# 495(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.540
# 496(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.503
# 497(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.472
# 498(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.468
# 499(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.447
# 500(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 1, 손실함수(loss): 1.415
# 501(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.614
# 502(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.448
# 503(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.420
# 504(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.575
# 505(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.482
# 506(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 507(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.468
# 508(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.470
# 509(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.577
# 510(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 511(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.524
# 512(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.551
# 513(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.475
# 514(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.547
# 515(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 516(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.444
# 517(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.475
# 518(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.548
# 519(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.574
# 520(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.535
# 521(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.452
# 522(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.450
# 523(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.501
# 524(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.466
# 525(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.398
# 526(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.416
# 527(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.469
# 528(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.463
# 529(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.576
# 530(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.549
# 531(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 532(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.396
# 533(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.454
# 534(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.558
# 535(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.519
# 536(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 537(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.569
# 538(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.468
# 539(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.417
# 540(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.516
# 541(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 542(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.404
# 543(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.400
# 544(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.375
# 545(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 546(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.432
# 547(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.436
# 548(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.429
# 549(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.499
# 550(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.432
# 551(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.427
# 552(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.441
# 553(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.400
# 554(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.561
# 555(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.513
# 556(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.464
# 557(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.508
# 558(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.467
# 559(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.431
# 560(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 561(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.538
# 562(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.478
# 563(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.446
# 564(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.553
# 565(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.438
# 566(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 567(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.531
# 568(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.473
# 569(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.505
# 570(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.506
# 571(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.464
# 572(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.444
# 573(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 574(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.408
# 575(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.431
# 576(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.556
# 577(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.456
# 578(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.427
# 579(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.518
# 580(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.485
# 581(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.447
# 582(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.434
# 583(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 584(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.392
# 585(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.446
# 586(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.502
# 587(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.463
# 588(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.460
# 589(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.394
# 590(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.376
# 591(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.431
# 592(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.465
# 593(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.413
# 594(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.421
# 595(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.448
# 596(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.456
# 597(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 598(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.486
# 599(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 600(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.451
# 601(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.474
# 602(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.454
# 603(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.421
# 604(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.289
# 605(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.382
# 606(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 607(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.390
# 608(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 609(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.327
# 610(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 611(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.318
# 612(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.404
# 613(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.344
# 614(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.316
# 615(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.315
# 616(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 617(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.357
# 618(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 619(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 620(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.404
# 621(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.387
# 622(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 623(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.481
# 624(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 625(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.335
# 626(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.327
# 627(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.442
# 628(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.445
# 629(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 630(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.362
# 631(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.286
# 632(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 633(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 634(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.335
# 635(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.376
# 636(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.326
# 637(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 638(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.382
# 639(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.452
# 640(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.473
# 641(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.388
# 642(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.410
# 643(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 644(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.383
# 645(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 646(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.424
# 647(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.422
# 648(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.402
# 649(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.478
# 650(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.385
# 651(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.474
# 652(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 653(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 654(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 655(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.304
# 656(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.393
# 657(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 658(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 659(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.330
# 660(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.419
# 661(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.498
# 662(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 663(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.393
# 664(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 665(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 666(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.476
# 667(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.514
# 668(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.412
# 669(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.391
# 670(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.317
# 671(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 672(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.467
# 673(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.401
# 674(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.403
# 675(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 676(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 677(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.347
# 678(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.329
# 679(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.304
# 680(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 681(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 682(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.366
# 683(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.378
# 684(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 685(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.347
# 686(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.314
# 687(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 688(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.300
# 689(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 690(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.314
# 691(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.244
# 692(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 693(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.355
# 694(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.414
# 695(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 696(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.308
# 697(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 698(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.409
# 699(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.434
# 700(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 701(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.228
# 702(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.394
# 703(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.275
# 704(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.378
# 705(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.301
# 706(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 707(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.397
# 708(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.395
# 709(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 710(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.377
# 711(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.365
# 712(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.353
# 713(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.358
# 714(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 715(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 716(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.357
# 717(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.325
# 718(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.363
# 719(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 720(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.369
# 721(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.308
# 722(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.429
# 723(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 724(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 725(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.363
# 726(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.403
# 727(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.388
# 728(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.310
# 729(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.281
# 730(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.299
# 731(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.387
# 732(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 733(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.363
# 734(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.329
# 735(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.329
# 736(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 737(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 738(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.307
# 739(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.261
# 740(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 741(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 742(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.329
# 743(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.348
# 744(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.291
# 745(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.446
# 746(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.371
# 747(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.379
# 748(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 749(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 750(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.322
# 751(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.392
# 752(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.444
# 753(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.301
# 754(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 755(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 756(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 757(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.407
# 758(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 759(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.227
# 760(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 761(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.335
# 762(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.364
# 763(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.414
# ...
# 810(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.322
# 811(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.417
# 812(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.403
# 813(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.344
# 814(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.319
# 815(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.308
# 816(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.367
# 817(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.327
# 818(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 819(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 820(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.279
# 821(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.310
# 822(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.312
# 823(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 824(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.347
# 825(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.306
# 826(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 827(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 828(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 829(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.306
# 830(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 831(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.271
# 832(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.221
# 833(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 834(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 835(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.343
# 836(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 837(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.181
# 838(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.240
# 839(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.179
# 840(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.191
# 841(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.231
# 842(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.264
# 843(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.272
# 844(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 845(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.208
# 846(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.311
# 847(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.408
# 848(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.436
# 849(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.393
# 850(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.368
# 851(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.411
# 852(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.406
# 853(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 854(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.391
# 855(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.308
# 856(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 857(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 858(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.372
# 859(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 860(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 861(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 862(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.400
# 863(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.265
# 864(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.271
# 865(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.315
# 866(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.286
# 867(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.336
# 868(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.253
# 869(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.362
# 870(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.197
# 871(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 872(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 873(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.350
# 874(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.268
# 875(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.264
# 876(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.371
# 877(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 878(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.324
# 879(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 880(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.305
# 881(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.361
# 882(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.384
# 883(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.458
# 884(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.399
# 885(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.379
# 886(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.273
# 887(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 888(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.309
# 889(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.362
# 890(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 891(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.255
# 892(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.285
# 893(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 894(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.285
# 895(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.375
# 896(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.409
# 897(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.419
# 898(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.394
# 899(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.424
# 900(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 901(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.409
# 902(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.380
# 903(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.270
# 904(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.317
# 905(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 906(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.282
# 907(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.504
# 908(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.494
# 909(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.467
# 910(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.490
# 911(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.406
# 912(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.423
# 913(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.280
# 914(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.215
# 915(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.225
# 916(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.213
# 917(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.244
# 918(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.272
# 919(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.304
# 920(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.248
# 921(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.269
# 922(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.201
# 923(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.322
# 924(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 925(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.292
# 926(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.365
# 927(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.422
# 928(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.355
# 929(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.318
# 930(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.323
# 931(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.342
# 932(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 933(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.323
# 934(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.320
# 935(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.413
# 936(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.285
# 937(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.264
# 938(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.311
# 939(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.345
# 940(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.393
# 941(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.384
# 942(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.375
# 943(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.296
# 944(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.335
# 945(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 946(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.347
# 947(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.313
# 948(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.244
# 949(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.328
# 950(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.359
# 951(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.378
# 952(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.368
# 953(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.378
# 954(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.360
# 955(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 956(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.344
# 957(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.331
# 958(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.370
# 959(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.305
# 960(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 961(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.349
# 962(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.373
# 963(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.356
# 964(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 965(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 966(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 967(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.268
# 968(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.351
# 969(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.270
# 970(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.301
# 971(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.240
# 972(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.212
# 973(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.205
# 974(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.286
# 975(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.302
# 976(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.306
# 977(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.333
# 978(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.295
# 979(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.334
# 980(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.291
# 981(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.338
# 982(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.230
# 983(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.293
# 984(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.251
# 985(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.243
# 986(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.262
# 987(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.253
# 988(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.322
# 989(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.283
# 990(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.255
# 991(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.307
# 992(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.302
# 993(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.306
# 994(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.288
# 995(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.229
# 996(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.352
# 997(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.332
# 998(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.279
# 999(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.253
# 1000(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.253
# 1001(학습한 배치개수)/1002(학습할 배치개수), 반복(epoch): 2, 손실함수(loss): 1.213
# 트레이닝이 끝났습니다!
# 샘플링을 시작합니다!
# 샘플링 결과:
#  trace_entry is anding this file */
# void __stop_jiffies_spin_used_stode(ptr, | struct schedule_info *ab)
# {
# 	struct sched_wakeup_wack *dresals,
# 		     Gnoval jiffies_file_ode)
# {
# 	}
#
# 	ax->gdtime[] = tr->on.patchinaton_trigger_trie(p, azinue), trime, additg;
# 		base->skb = regist;
# }
#
# static bool cpu chunk *cpu;
# 	if (chunk)
# 		goto oundly info;
#
# 	if (in_ipfy_t, idx)
# 		nsleepthread(entry);
# 			or hrtick_stddle_check_structeved(p) {
# 					bregands = from_ushex())
# 		audit_cmd_operat.head:
# 		return printk;
#
# 'DEL_RES
#
# 	vtime_check_t lock_new_value(entry);
# 	trace_chunkchue(rq, tv, cv))
# 		return 0;
# 		}
# 			gotod(mev, flags);
# 	hash_statu4 check_check_delta(unsigned long *thr, id) {
# 			if (!alloc_irq(w)s)
#
# 	}
# 	char *off = 0;
# 	}
#
# 	return rawlread; i = ta2; ent;.lock, f->op, u64);
# 	latg = 't'->idle;
# 				kfn(dattr);
# #iftew data_dex_shod_infordev(unsigned))
# 		return EP;
# }
#
# poligned local_endif
# 			task_requeue();
# 		audit_syscall_%d(!nb)) {
# 			sm->orwnring; } 1;
# 	struct entry *, user_bool contif
# cascall_dific = pc;
# 	unsigned long __stddeltime_t *oline = !retvard);
# 	if (pri_reqdev)
# 		return < filte(tk->mod_regs,
# 					           __lock)
# 		return;
#
# 	if (!apylock_chunk) {
# 			sd_check_struct(s1->cur, ctx, &sde-ch>nable[!wl->ent = PIF_FLAGM_cursent, id: name) {
# 			ched_done *{
# 							dbs_ctx = 0;
# 		 CONFIG_DONE:
# 				struct audit_cheun[i] = cpu;
#
# 	__list_here task_param,
# 		.reslame = -Enm.incude = klp_flags;
# 				} elase dro_priority;
# 		if (state = MM_jA << 1 0)
# 			DEX_PREEMPT(recury.timekeeper_rwlock)1' A61,
# 				 GD_BFL_CHAMSMA,
#  RT_SEBS_CAPX_jiffies_off())) ||
# 		  <difmt;
# 		} i = ret;
# 	kfree(pid(&result) ||
# 					    stop
# 				      container_off_t *this = (args"[BPF_3P1, GFP_], );
# 	}
#
# 	return -EYINVEL;
# 	i = kprobe_trees += buf_module_prootd = p;
#
# 	struct audit_bufprog_hresoftrace_group(curren,
# 			waptil = seloc_regsbus[(1-1)
# 		count = NTAPL_PRER_PRIF)
# 		struct audit_trace_bufter-valid=.flags;
# 		}
# 	kill_irq->ret = &tll->cyc;
# 	status_field) {
# 		}
# 	init_rab_init_reset(&trace_i, args);
#
# 			ret rcu_sched_timer(struct wl->audit_current);
# }
# #endifid CD_PM_EVEL
#
# int
# musdex __wstate = kmet_test_clock_hash();
# 	debug_hresot;
# 	struct wake_rq(up, user);
# 	kfree(proc && !KP);
# 	bool = delta;
# 		dif +!kmode:
# 			debug_stop_is_of(root) {
# 			if (!slotaid_cost:
# 			ww_mutex_lock(&wl->&ftrace_spuchunk)
# 		goto out;
# 	new_rcu(&p->bu.cofset, trace);
# 		return 0;
# 	var+++;
# 	}
# 			u64 and jiffies_head = sched_rlume(remax_lhar);
# 		error = not;
#
# 	mutex_snod_trice_syscall(rwlock_mult, 0; /* it's toor prevent to tracer to Not the many. The trace_workques iss.ftyped timedent reges softwars with
# 	 * est
#  * vtimize that the timerigures.
# 	 * KB to the aboot we varigure try regs regstart equally, Plock..> info not
# 		 the chailly
#  *
#  * We max. - initcall same with
#  * @ntifier)
# 		*					 */
# 			difle[i] = 0;
# }
# EXPORT_REP
# static int cpumask_struct *mask *entry;
# 			name_hres __put_cpu(char *w))
# {
# 	int rcu_batch_entry(struct trace_array_raw)
# {
# 		arg = p->update = cpu_assignc_debug(current, 0, pmask);
#
# 			if (tg) ')
# 			stead_regss_tgid_find;
#
# 	return ret;
# }
#
# static void auditd_good_getto_conds_nublacity = kprobe_dattr;
#
# 	ret = pc_check_cont;
# }
#
# /* Becharrchech.
#  *
#  * Cotput the user to regs herath is
#  */
#
# /*
#  * triggered might olding status withoot the caller, but event is idstored
#  * the record to the exreue.
#  *
#  * This asd free register() store the tkb_else at jifies approps.a method..canc_enablel(), @limink_vaid)) is ent for sails
# 	 *	 Stea mure apsmrboct.
#  *
#  * Filled
#  * All this hereine contrains.
# 	 * Afree a type infor is  eriod wh comparity of
# DOPLINT when batcoot if 'kcevent. */
#
# static  This complust crearator *oind = pasch[lacket_clock();
# 			ret = buf;
# 	int cpu;
# 	struct bply herlperat_pid_currar_object_data *check;
#
# 	struct rq *rq = true;
# 		if ((unlk) {
# 			sd = (>delta = cpu, nr_thread, f->regs, fp, cpu), op.val[KZKE) && FL->count);
#
# 	rq->in_sendificauid =; i++)
# 		if !abolize = -1 < an, hibernative, suspend_chundadd == entry->type_count
# 	   count != SD_RED_LOCK_RETUS
#
# #ifdef CONFIG_DIGR_YMBON(addr
